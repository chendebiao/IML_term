# %% [markdown]
# # Data exploration

# %% [markdown]
# ## import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read the data

# %%
npf = pd.read_csv("data/npf_train.csv")

npf = npf.set_index("date")

## Tell that "class4" is categorical variable. (R does this automatically.)
npf["class4"] = npf["class4"].astype("category")

npf = npf.drop(["id","partlybad"],axis=1)

npf
# Out:
#               class4  CO2168.mean  CO2168.std  CO2336.mean  CO2336.std  \
# date
# 2000-01-01  nonevent   384.462000    2.284996   384.164462    2.135062
# 2000-01-20  nonevent   374.884615    0.415185   374.703333    0.385179
# 2000-01-23  nonevent   373.496585    0.189497   373.382593    0.172958
# 2000-02-17  nonevent   378.600367    1.934180   378.464862    1.946536
# 2000-03-25        Ib   373.128684    1.096617   372.980000    1.047750
# ...              ...          ...         ...          ...         ...
# 2011-08-14  nonevent   377.541538    6.391551   377.802756    6.187754
# 2011-08-16  nonevent   381.016623    4.411571   381.030844    4.062115
# 2011-08-18  nonevent   386.687895   12.065627   386.284079   11.751004
# 2011-08-21  nonevent   379.279128   12.045785   379.363087   11.533353
# 2011-08-22  nonevent   384.443758    6.413297   384.364392    5.781036
#
#             CO242.mean  CO242.std  CO2504.mean  CO2504.std   Glob.mean  ...  \
# ...

# %% [markdown]
# ## variable explanations
# **CO2168**: Carbon monoxide concentration in ppb-units at 2168 measurement level (216.8 m) above Mast base
# **Glob**: Global shortwave solar radiation in wavelength range 0.3-4.8 µm
# **H2O168**: Water vapour concentration at 16.8 m height
# **NET**: Net radiation
# **NO168**: Nitrogen monoxide concentration in dry air at 16.8 m height
# **NOx168**: Nitrogen oxide concentration in dry air at 16.8 m height
# **O3168**: Ozone concentration in dry air at 16.8 m height
# **Pamb0**： Atmospheric pressure at ground level (180 m a.s.l.)
# **PAR**: Photosynthetically active radiation in wavelength range 400-700 nm
# **PTG**: Potential temperature gradient
# **RGlob**: Reflected shortwave radiation
# **RHIRGA168**: Relative humidity calculated from H₂O concentration and air temperature at 16.8 m height
# **RPAR**: Reflected photosynthetically active radiation in wavelength range 400-700 nm at 67 m height in the mast
# **SO2168**: Sulphur dioxide concentration in dry air at 16.8 m height
# **SWS**: Surface wetness sensor signal
# **T168**: Air temperature at 16.8 m height measured with Pt100 inside ventilated custom-made radiation shield
# **UV_A**: Ultraviolet A radiation in wavelength range 320-400 nm at 18 m height
# **UV_B**: Ultraviolet B radiation in wavelength range 280-320 nm at 18 m height
# **CS**: Condensation sink in the units of 1/s

# %% [markdown]
# ## class4 counts

# %%
# npf.describe()
npf.groupby('class4').size()
# Out:
# class4
# II          117
# Ia           29
# Ib           83
# nonevent    229
# dtype: int64

# %% [markdown]
# ## Correlation heatmaps

# %%
# all 'std's correlation heatma
npf_std = npf.loc[:,npf.columns.str.endswith('.std')]
f = plt.figure(figsize=(30, 30))
heatmap = sns.heatmap(npf_std.corr(method='pearson'), vmin=-1, vmax=1,cmap='bwr',annot=True,fmt=".2f")
heatmap.set_title('"std" Correlation Heatmap',fontdict={'fontsize':40}, pad=18);
plt.show()

# %%
# all 'mean's correlation heatma
npf_mean = npf.loc[:,npf.columns.str.endswith('.mean')]
f = plt.figure(figsize=(30, 30))
heatmap = sns.heatmap(npf_mean.corr(method='pearson'), vmin=-1, vmax=1,cmap='bwr',annot=True,fmt=".2f")
heatmap.set_title('"mean" Correlation Heatmap', fontdict={'fontsize':40}, pad=18);
plt.show()
